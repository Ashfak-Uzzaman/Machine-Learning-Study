# %%
import tensorflow as tf
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.utils import to_categorical

# Load dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize input data to range [0, 1]
x_train = x_train / 255.0
x_test = x_test / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Build the model
model = Sequential([
    Flatten(input_shape=(28, 28)),       # Flatten 28x28 images to 784-vector
    Dense(128, activation='relu'),       # Hidden layer 1
    Dense(64, activation='relu'),        # Hidden layer 2
    Dense(10, activation='softmax')      # Output layer (10 classes)
])

# Compile the model with Adam optimizer
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    x_train, y_train,
    epochs=10,
    batch_size=32,
    validation_data=(x_test, y_test)
)

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 14s 6ms/step - loss: 0.2392 - accuracy: 0.9311 - val_loss: 0.1431 - val_accuracy: 0.9549
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1038 - accuracy: 0.9678 - val_loss: 0.0984 - val_accuracy: 0.9691
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0719 - accuracy: 0.9777 - val_loss: 0.0939 - val_accuracy: 0.9700
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0542 - accuracy: 0.9827 - val_loss: 0.0870 - val_accuracy: 0.9737
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0432 - accuracy: 0.9861 - val_loss: 0.0913 - val_accuracy: 0.9725
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0357 - accuracy: 0.9882 - val_loss: 0.0828 - val_accuracy: 0.9751
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0307 - accuracy: 0.9900 - val_loss: 0.0779 - val_accuracy: 0.9795
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0241 - accuracy: 0.9920 - val_loss: 0.0892 - val_accuracy: 0.9770
# Epoch 9/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0226 - accuracy: 0.9926 - val_loss: 0.0968 - val_accuracy: 0.9765
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0177 - accuracy: 0.9941 - val_loss: 0.0922 - val_accuracy: 0.9787
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0922 - accuracy: 0.9787
# Test Accuracy: 0.9787

# %%
x='he'

print(x not in 'hi')
# Out:
# True
