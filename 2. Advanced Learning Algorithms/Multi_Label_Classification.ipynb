# %% [markdown]
# **Source:**<br>
# 1) https://www.youtube.com/watch?v=YyOuDi-zSiI&list=LL&index=2 <br>
# 2) https://github.com/Jcharis/Python-Machine-Learning/blob/master/Multi_Label_Text_Classification_with_Skmultilearn/

# %% [markdown]
# #### Package Import

# %%
# Load EDA (Exploratory Data Analysis) Pkgs
import pandas as pd
import numpy as np

# %%
# Load Data Visualization Pkgs
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ML Pkgs
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.metrics import accuracy_score,hamming_loss,classification_report

# %%
### Split Dataset into Train and Text
from sklearn.model_selection import train_test_split
# Feature engineering
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Multi Label Pkgs
from skmultilearn.problem_transform import BinaryRelevance
from skmultilearn.problem_transform import ClassifierChain
from skmultilearn.problem_transform import LabelPowerset
from skmultilearn.adapt import MLkNN

# %% [markdown]
# #### **Load & Visualize Data**

# %%
# Load Dataset
df = pd.read_csv("data\so_dataset_2_tags.csv")
df.size
# Out:
# 720

# %%
df.head()
# Out:
#                                                title                 tags  \
# 0  Flask-SQLAlchemy - When are the tables/databas...  ['python', 'mysql']
# 1        Combining two PHP variables for MySQL query     ['php', 'mysql']
# 2  'Counting' the number of records that match a ...     ['php', 'mysql']
# 3  Insert new row in a table and auto id number. ...     ['php', 'mysql']
# 4             Create Multiple MySQL tables using PHP     ['php', 'mysql']
#
#    mysql  python  php
# 0      1     1.0  0.0
# 1      1     0.0  1.0
# 2      1     0.0  1.0
# 3      1     0.0  1.0
# 4      1     0.0  1.0

# %%
df.loc[0]
# Out:
# title     Flask-SQLAlchemy - When are the tables/databas...
# tags                                    ['python', 'mysql']
# mysql                                                     1
# python                                                  1.0
# php                                                     0.0
# Name: 0, dtype: object

# %%
df.loc[0].title
# Out:
# 'Flask-SQLAlchemy - When are the tables/databases created and destroyed?'

# %%
df.dtypes
# Out:
# title      object
# tags       object
# mysql       int64
# python    float64
# php       float64
# dtype: object

# %%
# Convert mysql to float
df['mysql']=df['mysql'].astype(float)

# %%
df.dtypes
# Out:
# title      object
# tags       object
# mysql     float64
# python    float64
# php       float64
# dtype: object

# %%
sns.countplot(data=df, x='python')
# Out:
# <Axes: xlabel='python', ylabel='count'>

# %%
df['python'].value_counts()
# Out:
# python
# 0.0    82
# 1.0    62
# Name: count, dtype: int64
